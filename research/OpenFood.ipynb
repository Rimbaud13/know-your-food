# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import word2vec
import re
import json
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch(hosts=['163.172.173.89:53837'])

# %%
products = pd.read_csv('data/products.csv', index_col='id')
nutrients = pd.read_csv('data/nutrients.csv', index_col='id')
product_nutrients = pd.read_csv('data/product_nutrients.csv', index_col=['product_id', 'nutrient_id'])
categories = pd.read_csv('data/categories.csv', index_col='id')
categorisations = pd.read_csv('data/categorisations.csv', index_col=['category_id', 'categorisable_id'])
images = pd.read_csv('data/images.csv', index_col='id')

# %%
def parse_fr(value):
    if pd.isnull(value):
        return np.nan
    langs = {lang: name for lang, name in re.findall(r'"([^"]+)" ?=> ?"([^"]+)"', value)}
    return langs.get('fr', np.nan)

# %%
def join(i1, k1, i2, k2):
    return i1.reset_index().join(i2.reset_index().set_index(k2), on=k1, lsuffix='_')

# %%
products['fr'] = products.name_translations.apply(parse_fr)
products.fr.count()
# Out:
# 2028

# %%
nutrients['fr'] = nutrients.name_translations.apply(parse_fr)
nutrients.fr.count()
# Out:
# 40

# %%
fld_products = ['fr', 'barcode', 'unit', 'quantity', 'portion_quantity', 'alcool_by_volume']
sel_products = products[pd.notnull(products.fr)][fld_products].fillna(value=-1)
sel_products.head()
# Out:
#                                        fr        barcode unit  quantity  \
# id
# 1192                           Saint-Omer  3162330052641   ml     500.0
# 1194                             Heineken  7610055020750    g     500.0
# 1125              granini : orange-mangue  7610235004884   ml    1000.0
# 1168           AARBERG: Sucre en morceaux  7610278041105    g    1000.0
# 1153  Belle France : Lentilles, cuisinées  3258561211534    g     410.0
#
#       portion_quantity  alcool_by_volume
# id
# 1192              -1.0               5.0
# 1194              -1.0               5.0
# 1125              -1.0               0.0
# 1168              -1.0               0.0
# 1153             200.0               0.0

# %%
fld_nutrients = ['product_id', 'fr', 'per_portion', 'per_day', 'per_hundred', 'unit']
sel_nutrients = join(product_nutrients, 'nutrient_id', nutrients, 'id')[fld_nutrients].fillna(value=-1)
sel_nutrients.head()
# Out:
#    product_id                fr  per_portion  per_day  per_hundred  unit
# 0         971           Énergie        117.0      6.0       2430.0    kJ
# 1         971    Énergie (kCal)         -1.0     -1.0        581.0  kCal
# 2         971         Protéines          2.0      4.0         10.0     g
# 3         971  Matières grasses          8.0      2.0         42.0     g
# 4         971          Glucides          7.0      3.0         38.0     g

# %%
prods = []
for idx, p in sel_products.iterrows():
    obj = p.to_dict()
    obj['nutrients'] = []
    for _, nut in sel_nutrients[sel_nutrients.product_id == idx].iterrows():
        obj['nutrients'].append(nut.to_dict())
    action = { 
        'index': {
            '_index': 'kyf',
            '_type': 'default',
            '_id': obj['barcode']
        }
    }
    prods.append(action)
    prods.append(obj)

# %%
len(prods)
# Out:
# 4056

# %%
prods[3]
# Out:
# {'alcool_by_volume': 5.0,
#  'barcode': '7610055020750',
#  'fr': 'Heineken',
#  'nutrients': [],
#  'portion_quantity': -1.0,
#  'quantity': 500.0,
#  'unit': 'g'}

# %%
es.bulk(prods)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id

#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269297352',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613312051993',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800969129',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7614800216085',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809017333',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610846044170',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800997894',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616700187809',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '4104420055469',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610846707648',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613312050330',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200067654',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610167617114',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '4104420146945',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610095183002',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610803009235',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800975236',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610849861026',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610803008719',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829084438',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800996866',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613331111395',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3502110003782',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613356130678',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829084421',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807015843',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613331111388',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611100053112',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617027916011',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269296812',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809082195',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610100010316',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809124451',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610848669036',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807026566',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613331182319',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800010067',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610827558184',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '4062300374744',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200027078',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617027788717',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '0024000001669',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809018910',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269296775',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269309185',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200206626',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800010050',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269228929',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616700028836',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613032632496',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610848718932',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269297239',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '8000320030093',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '8413164007617',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7804600650077',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269248941',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613312037423',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7640122431202',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613312037409',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800004097',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '5000159459228',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610818340347',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610818313952',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610818340323',
# ...
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829701052',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613331506238',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809132579',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807240368',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7640157480039',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '76129704',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '5410228164845',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610800047674',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807240993',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807240672',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829103016',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807240733',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3211200997329',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610846965260',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807227291',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7640159760030',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807240849',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613331007308',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610849260447',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829135604',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '8410310604164',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '5411633750050',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '8005369000779',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829639492',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610848667209',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807120998',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3159470204429',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610849261963',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807133486',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807133936',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7615200109403',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611100454049',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610829138223',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807121049',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610827641213',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807111866',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807120820',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610100023606',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610900122776',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610900019571',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690701035',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610211012407',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611100053891',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610845293913',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3223920730124',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '76410482',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807120929',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809107706',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '8002210115699',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610807121032',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610900063734',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3073780515931',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610818191802',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690309279',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690309316',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '87157215',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200053510',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610809008706',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610900150106',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611700004217',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610434012130',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610434012222',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3273670002026',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610849322015',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690309248',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617027018593',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617027056267',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690312538',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690309231',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690311982',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610405075751',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '22129956',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '2188547003000',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616800101019',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616800101125',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7611690314082',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200422262',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617300706117',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200313980',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '22129932',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269423980',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '3563490010999',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616700165159',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7613269185772',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7617400020212',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '5050083262203',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7616800101040',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   {'index': {'_id': '7610200010216',
#     '_index': 'kyf',
#     '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#     '_type': 'default',
#     '_version': 1,
#     'status': 201}},
#   ...],
#  'took': 3987}

# %%
data = re.sub('\s+', ' ', re.sub('[:\.\(\)0123456789%,–\?\\\&\']', '', ' '.join(product_fr.values).replace('-', ' ').lower()))

# %%
with open('data/names.txt', 'w') as f:
    f.write(data)
    f.close()

# %%
word2vec.word2phrase('data/names.txt', 'data/names-phrases.txt', verbose=True)

# %%
word2vec.word2vec('data/names.txt', 'data/names-model.bin', size=100, verbose=True)

# %%
word2vec.word2clusters('data/names.txt', 'data/names-clusters.txt', 100, verbose=True)

# %%
model = word2vec.load('data/names-model.bin')

# %%
clusters = word2vec.load_clusters('data/names-clusters.txt')

# %%
model.vocab

# %%
model.vectors.shape

# %%
indexes, metrics = model.analogy(pos=['snack'], neg=[], n=10)
model.generate_response(indexes, metrics).tolist()
